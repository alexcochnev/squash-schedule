# %%
import requests
from datetime import datetime, timedelta
import pandas as pd
import re
import json

# %%
week = {0:'ПН', 1:'ВТ', 2:'СР', 3:'ЧТ', 4:'ПТ', 5:'СБ', 6:'ВС'}

# %% [markdown]
# Дубровка

# %%
headers1 = {
'authorization': 'Bearer yusw3yeu6hrr4r9j3gw6, User ec8ecfaf1072c39041a7cc582a8ac232',
'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.141 Safari/537.36 OPR/73.0.3856.344'
}

# %%
#ближайшие 2 недели, вечер
df1 = pd.DataFrame(columns=['date','week','17:00','18:00','19:00','20:00','21:00','22:00'])
for i in range(14):
    try:
        answer={}
        raw_date = datetime.today() + timedelta(i)
        date = raw_date.strftime('%Y-%m-%d')
        answer['week']=week[raw_date.weekday()]
        day_resp = requests.get(f'https://n136076.yclients.com/api/v1/book_times/144563/-1/{date}?service_ids%5B%5D=2177728', headers=headers1).json()
        answer['date'] = datetime.strptime(day_resp[0]['datetime'].replace('+0300', ''), '%Y-%m-%dT%H:%M:%S').strftime('%d.%m')
        for time in day_resp:
            if time['time'] in ['17:00','18:00','19:00','20:00','21:00','22:00']:
                answer[time['time']]='+'
        df1 = df1.append(answer, ignore_index=True)
    except IndexError:
        pass
print('Дубровка')
df1.fillna('')
# Out:
# Дубровка
#      date week 17:00 18:00 19:00 20:00 21:00 22:00
# 0   14.02   ВС                                   +
# 1   15.02   ПН     +     +     +                 +
# 2   16.02   ВТ                                   +
# 3   17.02   СР     +     +                       +
# 4   18.02   ЧТ           +                       +
# 5   19.02   ПТ     +     +     +     +     +     +
# 6   20.02   СБ     +     +     +     +     +     +
# 7   21.02   ВС     +     +     +           +     +
# 8   22.02   ПН     +     +     +     +     +     +
# 9   23.02   ВТ     +     +     +           +     +
# 10  24.02   СР     +     +     +                 +
# 11  25.02   ЧТ     +                       +     +
# 12  26.02   ПТ     +     +     +     +     +     +
# 13  27.02   СБ     +     +     +     +     +     +

# %% [markdown]
# # Шаболовка

# %%
headers2 = {
'authorization': 'Bearer yusw3yeu6hrr4r9j3gw6',
'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.141 Safari/537.36 OPR/73.0.3856.344'
}

# %%
#ближайшие 2 недели
df2 = pd.DataFrame(columns=['date','week','17:00','18:00','19:00','20:00','21:00','22:00'])
for i in range(14):
    try:
        answer={}
        raw_date = datetime.today() + timedelta(i)
        date = raw_date.strftime('%Y-%m-%d')
        answer['week'] = week[raw_date.weekday()]
        day_resp = requests.get(f'https://n116979.yclients.com/api/v1/book_times/127578/-1/{date}?service_ids%5B%5D=1705604', headers=headers2).json()
        answer['date'] = datetime.strptime(day_resp[0]['datetime'].replace('+0300', ''), '%Y-%m-%dT%H:%M:%S').strftime('%d.%m')
        for time in day_resp:
            if time['time'] in ['17:00','18:00','19:00','20:00','21:00','22:00']:
                answer[time['time']] = '+'
        df2 = df2.append(answer, ignore_index=True)
    except IndexError:
        pass
print('Шаболовка')
df2.fillna('')
# Out:
# Шаболовка
#      date week 17:00 18:00 19:00 20:00 21:00 22:00
# 0   15.02   ПН     +
# 1   16.02   ВТ     +                             +
# 2   17.02   СР     +
# 3   18.02   ЧТ     +
# 4   19.02   ПТ                                   +
# 5   20.02   СБ     +           +     +     +     +
# 6   21.02   ВС     +     +     +     +     +     +
# 7   22.02   ПН     +                             +
# 8   23.02   ВТ     +                             +
# 9   24.02   СР     +     +                       +
# 10  25.02   ЧТ     +                             +
# 11  26.02   ПТ     +                       +     +
# 12  27.02   СБ     +     +     +     +     +     +
# 13  28.02   ВС     +     +     +     +     +     +

# %% [markdown]
# # Ленинка

# %%
response = json.loads(re.sub(r'[\(\)\;]','', requests.get('https://api.sportbs.net/v1_0/model/index/3148').text))
df3 = pd.DataFrame(columns=['date','week','17:00','18:00','19:00','20:00','21:00','22:00'])
for i in range(14):
    try:
        raw_date = datetime.today() + timedelta(i)
        date = raw_date.strftime('%Y-%m-%d')
        answer={}
        answer['week'] = week[raw_date.weekday()]
        answer['date'] = raw_date.strftime('%d.%m')
        for i in range(17,23):
            sec = str(i*3600)
            if sec in response['days'][date]['hours'] and len(response['days'][date]['hours'][sec]) == 3: pass
            else:
                answer[f'{i}:00'] = '+'
        df3 = df3.append(answer, ignore_index=True)
    except IndexError:
        pass
print('Ленинка')
df3.fillna('')
# Out:
# Ленинка
#      date week 17:00 18:00 19:00 20:00 21:00 22:00
# 0   15.02   ПН     +     +                 +
# 1   16.02   ВТ                                   +
# 2   17.02   СР     +
# 3   18.02   ЧТ
# 4   19.02   ПТ
# 5   20.02   СБ     +     +     +           +     +
# 6   21.02   ВС                       +     +     +
# 7   22.02   ПН                       +           +
# 8   23.02   ВТ                                   +
# 9   24.02   СР     +                             +
# 10  25.02   ЧТ                                   +
# 11  26.02   ПТ
# 12  27.02   СБ     +     +     +     +     +     +
# 13  28.02   ВС           +           +     +     +

# %%
month = '02'
day = ['01','02','03','04','05']

# %%
for d in day:
    day_resp = requests.get(f'https://n136076.yclients.com/api/v1/book_times/144563/-1/2021-{month}-{d}?service_ids%5B%5D=2177728', headers=headers).json()
    answer = datetime.strptime(day_resp[0]['datetime'].replace('+0300', ''), '%Y-%m-%dT%H:%M:%S').strftime('%d.%m') + ': '
    for time in day_resp:
        answer = answer + time['time'] + ' '
    print(answer)
